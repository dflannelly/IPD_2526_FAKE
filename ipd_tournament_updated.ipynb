# %%
from platform import python_version
python_version()
# Out:
# '3.12.7'

# %%
import random
from importlib import reload

from __future__ import print_function
#os.path.join(os.path.dirname(__file__))
##### 
# Computer Science and Software Engineering
# PLTW AP CS Principles
# (c)2014 Project Lead The Way, Inc.
#
# Activity 1.3.9 Tools for Collaboration
# Project 1.3.10 Collaborating on a Project
# 
# To run a tournament, execute this file. 
# Place each team's strategy in a file in the same directory as this file.
# Tournament results saved to tournament.txt in this directory.
#
# prisoners_dilemma.py automates competition among different strategies
# for the Iterative Prisoners Dilemma, the canonical game of game-theory.

# Each strategy is pitted against each other strategy for 100 to 200 rounds.
# The results of all previous rounds within a 100-200 round stretch are known
# to both players. 
#
# play_tournament([team0, team1, team2]) executes a tournament and writes to tournament.txt
#
# Each team's strategy should be coded in their assigned Python file, called a module.
# Each player should have their own .py file containing 
# three strings team_name, strategy_name, and strategy_description
# and a function move(my_history, their_history, my_score, their_score)
# 
# By default, when executing this file, [example0, example1, example2, example3] 
# play a tournament. To run the tournament of [team, team1, team1, example1]:
# scores, moves, reports = main_play([team1]*3+[example1])
# section0, section1, section2, section3 = reports
#######
import random
import os.path              
    
import AJ,Angels_F,Chev_F,DeclareWar,defRealFunct_F,DM_F,EthanC_F,Jesters_F,johnegbert_f,June_bug_F,kuba_f,Lutz_F,Mango_F,robertLewandowski_F,Team25,The_Finnegansy_F,Tit_for_tat_f,Torrential_f,trustMe_F,VeggieBowl_F,Vinictore,youLost


modules = [AJ,Angels_F,Chev_F,DeclareWar,defRealFunct_F,DM_F,EthanC_F,Jesters_F,johnegbert_f,June_bug_F,kuba_f,Lutz_F,Mango_F,robertLewandowski_F,Team25,The_Finnegansy_F,Tit_for_tat_f,Torrential_f,trustMe_F,VeggieBowl_F,Vinictore,youLost]

for module in modules:
    reload(module)
    print ('reloaded',module)
    for required_variable in ['team_name', 'strategy_name', 'strategy_description']:
        if not hasattr(module, required_variable):
            setattr(module, required_variable, 'missing assignment')

def main_play(modules):
    '''main_play plays a tournament and outputs results to screen and file.
    This function is called once when this file is executed.
    modules: a list of modules such as [team1, team2]    
    
    Returns:
        scores:
        moves:
        sections: a list of [str, str, str, list of str]    
            '''
    scores, moves = play_tournament(modules)
    section0, section1, section2, section3 = make_reports(modules, scores, moves)
    code = make_code_string(modules)
    # On screen, include the first three out of four sections of the report.
    print(section0+section1+section2)
    # To file output, store all teams' code and all teams' section 3 reports.
    post_to_file(section0+section1+section2 + code + ''.join(section3))
    return scores, moves, [section0, section1, section2, section3]
        
def play_tournament(modules):
    '''Each argument is a module name
    Each module must contain 
        team_name: a string
        strategy_name: a string
        strategy_description: a string
        move: A function that returns 'c' or 'b'
    '''
    zeros_list = [0]*len(modules) # to initialize each player's head-to-head scores
    scores = [zeros_list[:] for module in modules] # Copy it or it's only 1 list
    moves = [zeros_list[:] for module in modules] # Copy it or it's only 1 list
    for first_team_index in range(len(modules)):
        for second_team_index in range(first_team_index):
            player1 = modules[first_team_index]
            player2 = modules[second_team_index]
            score1, score2, moves1, moves2 = play_iterative_rounds(player1, player2)
            capitalize(moves1, moves2)
            scores[first_team_index][second_team_index] = score1/len(moves1) # int division not an issue
            moves[first_team_index][second_team_index] = moves1
            # Redundant, but record this for the other player, from their perspective
            scores[second_team_index][first_team_index] = score2/len(moves2) 
            moves[second_team_index][first_team_index] = moves2
        # Playing yourself doesn't do anything
        scores[first_team_index][first_team_index] = 0
        moves[first_team_index][first_team_index] = ''
    return scores, moves


def play_iterative_rounds(player1, player2):
    '''
    Plays a random number of rounds (between 100 and 200 rounds) 
    of the iterative prisoners' dilemma between two strategies.
    player1 and player2 are modules.
    Returns 4-tuple, for example ('cc', 'bb', -200, 600) 
    but with much longer strings 
    '''
    number_of_rounds = random.randint(100, 200)
    moves1 = ''
    moves2 = ''
    score1 = 0
    score2 = 0
    for round in range(number_of_rounds):
        score1, score2, moves1, moves2 = play_round(player1, player2, score1, score2, moves1, moves2)
    return (score1, score2, moves1, moves2)
    
def play_round(player1, player2, score1, score2, moves1, moves2):
    '''
    Calls the move() function from each module which return
    'c' or 'b' for collude or betray for each player.
    The history is provided in a string, e.g. 'ccb' indicates the player
    colluded in the first two rounds and betrayed in the most recent round.
    Returns a 2-tuple with score1 and score2 incremented by this round
    '''
    
    RELEASE = 0 # (R, "reward" in literature) when both players collude
    TREAT = 100 # (T, "temptation" in literature) when you betray your partner
    SEVERE_PUNISHMENT = -500 # (S, "sucker" in literature) when your partner betrays you
    PUNISHMENT = -250 # (P) when both players betray each other
    
    # Keep T > R > P > S to be a Prisoner's Dilemma
    # Keep 2R > T + S to be an Iterative Prisoner's Dilemma
    
    ERROR = -250
    
    # Get the two players' actions and remember them.
    action1 = player1.move(moves1, moves2, score1, score2)
    action2 = player2.move(moves2, moves1, score2, score1)
    if (type(action1) != str) or (len(action1) != 1):
        action1=' '
    if (type(action2) != str) or (len(action2) != 1):
        action2=' '
    
    # Change scores based upon player actions.
    actions = action1 + action2
    if actions == 'cc':
        # Both players collude; get reward.
        score1 += RELEASE
        score2 += RELEASE
    elif actions == 'cb':
        # Player 1 colludes, player 2 betrays; get severe, treat.
        score1 += SEVERE_PUNISHMENT
        score2 += TREAT
    elif actions == 'bc':
        # Player 1 betrays, player 2 colludes; get treat, severe.
        score1 += TREAT
        score2 += SEVERE_PUNISHMENT 
    elif actions == 'bb':
        # Both players betray; get punishment.   
        score1 += PUNISHMENT
        score2 += PUNISHMENT     
    else:
        # Both players get the "error score" if someone's code returns an improper action.
        score1 += ERROR
        score2 += ERROR
    
    # Append the actions to the previous histories.
    if action1 in 'bc':
        moves1 += action1
    else:
        moves1 += ' '
    if action2 in 'bc':
        moves2 += action2
    else:
        moves2 += ' '
                    
    # Return scores incremented by this round's results.
    return (score1, score2, moves1, moves2)  
            
def make_reports(modules, scores, moves):
    section0 = make_section0(modules, scores)
    section1 = make_section1(modules, scores)
    section2 = make_section2(modules, scores)
    
    section3 = []
    for index in range(len(modules)):
        section3.append(make_section3(modules, moves, scores, index))
    return section0, section1, section2, section3
        
def make_section0(modules, scores):
    '''
    Produce the following string:
    ----------------------------------------------------------------------------
    Section 0 - Line up
    ----------------------------------------------------------------------------
    Player 0 (P0): Team name 0, Strategy name 0,
         Strategy 0 description
    Player 1 (P1): Team name 1, Strategy name 1, 
         Strategy 1 description
    ''' 
    section0 = '-'*80+'\n'
    section0 += 'Section 0 - Line up\n'
    section0 += '-'*80+'\n'
    for index in range(len(modules)):
        section0 += 'Player ' + str(index) + ' (P' + str(index) + '): '
        section0 += str(modules[index].team_name) + ', ' + str(modules[index].strategy_name) + '\n'
        strategy_description = str(modules[index].strategy_description)
        # Format with 8 space indent 80 char wide
        while len(strategy_description) > 1:
            newline = strategy_description[:72].find('\n')
            if newline> -1:
                section0 += ' '*8 + strategy_description[:newline+1]
                strategy_description = strategy_description[newline+1:]
            else:
                section0 += ' '*8 + strategy_description[:72] + '\n'
                strategy_description = strategy_description[72:]
    return section0
    
def make_section1(modules, scores):
    '''
    ----------------------------------------------------------------------------
    Section 1 - Player vs. Player
    ----------------------------------------------------------------------------
    A column shows pts/round earned against each other player:      
                P0    P1         
    vs. P0 :     0   100          
    vs. P1 :  -500     0             
    TOTAL  :  -500   100
    '''
    # First line
    section1 = '-'*80+'\nSection 1 - Player vs. Player\n'+'-'*80+'\n'
    section1 += 'Each column shows pts/round earned against each other player:\n'
    # Second line
    section1 += '        '
    for i in range(len(modules)):
          section1 += '{:>7}'.format('P'+str(i))
    section1 += '\n'
    # Add one line per team
    for index in range(len(modules)):
        section1 += 'vs. P' + str(index) + ' :'
        for i in range(len(modules)):
            section1 += '{:>7}'.format(scores[i][index])
        section1 += '\n'

    # Last line
    section1 += 'TOTAL  :'
    for index in range(len(modules)):
        section1 += '{:>7}'.format(sum(scores[index]))     
    return section1+'\n'
    
def make_section2(modules, scores):
    '''
    ----------------------------------------------------------------------------
    Section 2 - Leaderboard
    ----------------------------------------------------------------------------
    Average points per round:
    Team name (P#):  Score       with strategy name
    Champ10nz (P0):   100 points with Loyal
    Rockettes (P1):  -500 points with Backstabber
    ''' 
    section2 = '-'*80+'\nSection 2 - Leaderboard\n'+'-'*80+'\n'
    section2 += 'Average points per round:\n'
    section2 += 'Team name (P#):  Score      with strategy name\n'
    
    # Make a list of teams' 4-tuples
    section2_list = []
    for index in range(len(modules)):
        section2_list.append((modules[index].team_name,
                              'P'+str(index),
                              str(sum(scores[index])/len(modules)),
                              str(modules[index].strategy_name)))
    section2_list.sort(key=lambda x: float(x[2]), reverse=True)

    # Generate one string per team
    # Rockettes (P1):  -500 points with Backstabber
    for team in section2_list:
        team_name, Pn, n_points, strategy_name = team
        section2 += '{:<10}({}): {:>10} points with {:<40}\n'.format(team_name[:10], Pn, n_points, strategy_name[:40])                       
    return section2 
    
def make_section3(modules, moves, scores, index):
    '''Return a string with information for the player at index, like:
    ----------------------------------------------------------------------------
    Section 3 - Game Data for Team Colloid c=-500 b=-250 C=0 B=+100
    ----------------------------------------------------------------------------
    -133 pt/round: Colloid (P6) "Collude every 3rd round"
    -233 pt/round: 2PwnU (P8) "Betray, then alternate"
    bBcBbCbBcBbCbBcBbCbBcBbCbBcBbCbBcBbCbBcBbCbBcBbCbBcBbCbBcBbCbBcBbCbBcBbCbBcB
    bcBcbCbcbcbCBcbcbCBcbcbCBcbcbCBcbcbCBcbcbCBcbcbCBcbcbCBcbcbCBcbcbCBcbcbCBcbc
    '''
    section3 = '-'*80+'\nSection 3 - Game Data for Team '
    section3 += modules[index].team_name + '\n'
    section3 += '-'*80+'\n'
    # Make 4 lines per opponent
    for opponent_index in range(len(modules)):
        if opponent_index != index:
            # Line 1
            section3 += str(scores[index][opponent_index])
            section3 += ' pt/round: ' + modules[index].team_name +'(P'
            section3 += str(index)+') "'+modules[index].strategy_name + '"\n'
            # Line 2
            section3 += str(scores[opponent_index][index])
            section3 += ' pt/round: ' + modules[opponent_index].team_name +'(P'
            section3 += str(opponent_index)+') "'+modules[opponent_index].strategy_name + '"\n'
            # Lines 3-4
            hist1, hist2 =  capitalize(moves[index][opponent_index], moves[opponent_index][index])
            while len(hist1) > 1:
                section3 += hist1[:80] + '\n'
                section3 += hist2[:80] + '\n\n'
                hist1 = hist1[80:]
                hist2 = hist2[80:]
            section3 += '-'*80 + '\n'
    return section3
                                                    
def capitalize(history1, history2):
    '''Accept two strings of equal length.
    Return the same two strings but capitalizing the opponent of 'c' each round.
    '''
    caphistory1, caphistory2 = '', ''
    for i in range(len(history1)):
        p1 = history1[i]
        p2 = history2[i]
        if p1 == 'c':
            p2 = p2.upper()
        if p2 in 'cC':
            p1 = p1.upper()
        caphistory1 += p1    
        caphistory2 += p2  
    return caphistory1, caphistory2
    
def make_code_string(modules):
    '''Returns a string of the code from each file.
    '''
    code = '-'*80 + '\n'
    code += 'Code of each player\'s algorithm\n'
    code = '-'*80 + '\n'
    for index in range(len(modules)):
        players_code_filename = str(modules[index]).split(' ')[1].replace('\'','')
        directory = os.path.dirname(os.path.abspath('__file__'))  
        print(directory)
        filename = os.path.join(directory, players_code_filename)
        players_code_file = open(filename+'.py', 'r')
        code += '-'*80 + '\n'
        code += players_code_filename
        code +='-'*80 + '\n'
        code += ''.join(players_code_file.readlines())
    return code

def copy_template():
    '''Transfer code in team0.py to team1.py though team14.py
    '''
    directory = os.path.dirname(os.path.abspath('__file__'))  
    with open(os.path.join(directory, 'team0.py'), 'r') as sourcefile:
        source = sourcefile.readlines()
    for i in range(1, 15):
        target = 'team'+str(i)+'.py'
        filename = os.path.join(directory, target)
        with open(filename, 'w') as target_file:
            target_file.write(''.join(source))                                   
                     
def post_to_api():
    pass

def post_to_local_html():
    pass
    
def post_to_file(string, filename='tournament.txt', directory=''):
    '''Write output in a txt file.
    '''
    # Use the same directory as the python script
    if directory=='':
        directory = os.path.dirname(os.path.abspath('__file__'))  
    # Name the file tournament.txt
    filename = os.path.join(directory, filename)
    # Create the file for the round-by-round results
    filehandle = open(filename,'w')
    filehandle.write(string)
 
### Call main_play() if this file is executed
if __name__ == '__main__':
    scores, moves, reports = main_play(modules)   
    section0, section1, section2, section3 = reports
# Out:
# reloaded <module 'AJ' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\AJ.py'>
# reloaded <module 'Angels_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\Angels_F.py'>
# reloaded <module 'Chev_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\Chev_F.py'>
# reloaded <module 'DeclareWar' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\DeclareWar.py'>
# reloaded <module 'defRealFunct_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\defRealFunct_F.py'>
# reloaded <module 'DM_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\DM_F.py'>
# reloaded <module 'EthanC_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\EthanC_F.py'>
# reloaded <module 'Jesters_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\Jesters_F.py'>
# reloaded <module 'johnegbert_f' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\johnegbert_f.py'>
# reloaded <module 'June_bug_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\June_bug_F.py'>
# reloaded <module 'kuba_f' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\kuba_f.py'>
# reloaded <module 'Lutz_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\Lutz_F.py'>
# reloaded <module 'Mango_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\Mango_F.py'>
# reloaded <module 'robertLewandowski_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\robertLewandowski_F.py'>
# reloaded <module 'Team25' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\Team25.py'>
# reloaded <module 'The_Finnegansy_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\The_Finnegansy_F.py'>
# reloaded <module 'Tit_for_tat_f' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\Tit_for_tat_f.py'>
# reloaded <module 'Torrential_f' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\Torrential_f.py'>
# reloaded <module 'trustMe_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\trustMe_F.py'>
# reloaded <module 'VeggieBowl_F' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\VeggieBowl_F.py'>
# reloaded <module 'Vinictore' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\Vinictore.py'>
# reloaded <module 'youLost' from 'C:\\Users\\dflannelly\\Documents\\GitHub\\IPD_2526_FAKE\\youLost.py'>
# Analyzing opponent history:
# Total betrayals (high numbers): 0
# Half or fewer were betrayals -> Random choice: b
# Analyzing opponent history: c
# Checking move: c
# Total betrayals (high numbers): 0
# Half or fewer were betrayals -> Random choice: c
# Analyzing opponent history: cb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 1
# Half or fewer were betrayals -> Random choice: b
# Analyzing opponent history: cbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 2
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 3
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 4
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 5
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 6
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 7
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 8
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 9
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbc
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Total betrayals (high numbers): 9
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 10
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbbcbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 11
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 12
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbbcbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 13
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbbcbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 14
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbbcbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 15
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 16
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 17
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 18
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 19
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 20
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 21
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 22
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 23
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 24
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 25
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 26
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 27
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 28
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 29
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 30
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 31
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 32
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 33
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 34
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 35
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 36
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 37
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 38
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 39
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: cbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
# ...
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 88
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: bbcbbbcbbbbcbbcbbcbcbbbbbbbccbbcbbbbbbcbbbbbbcbbccccbbbbbbcbbbbbbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbbcbccbbbbbbb
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: c
# Checking move: c
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 89
# More than half were betrayals -> Random choice: b
# Analyzing opponent history: bbcbbbcbbbbcbbcbbcbcbbbbbbbccbbcbbbbbbcbbbbbbcbbccccbbbbbbcbbbbbbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbbcbccbbbbbbbb
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: c
# Checking move: c
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Total betrayals (high numbers): 90
# More than half were betrayals -> Random choice: c
# Analyzing opponent history: bbcbbbcbbbbcbbcbbcbcbbbbbbbccbbcbbbbbbcbbbbbbcbbccccbbbbbbcbbbbbbbbbbbbbbcbbbbbbbbbbbbbbbbbbbbbbbbcbccbbbbbbbbb
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: c
# Checking move: c
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: c
# Checking move: c
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# Checking move: b
#  -> This is a betrayal (High)!
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
"""
Scalable Iterative Prisoner's Dilemma Tournament
Automatically loads all listed teams and outputs full results with ranks.
"""

import random
import os
from importlib import reload

# ---------------------------
# List your team modules here (without .py)
# ---------------------------
team_modules = [
    "defRealFunct", "kuba", "youLost", "Chev", "AJ", "DM", "EthanC",
    "Jesters", "June_bug", "RDGamblers", "robertLewandowski", "savior",
    "The_Finnegansy", "Tit_for_tat", "Torrential", "trustMe", "Y"
]

# ---------------------------
# Import and reload modules
# ---------------------------
modules = []
for name in team_modules:
    try:
        module = __import__(name)
        reload(module)
        for attr in ['team_name', 'strategy_name', 'strategy_description', 'move']:
            if not hasattr(module, attr):
                setattr(module, attr, 'missing assignment')
        modules.append(module)
        print(f"Loaded and reloaded module: {name}")
    except Exception as e:
        print(f"Error loading module {name}: {e}")

# ---------------------------
# Tournament logic
# ---------------------------
def play_round(player1, player2, score1, score2, moves1, moves2):
    RELEASE = 0
    TREAT = 100
    SEVERE_PUNISHMENT = -500
    PUNISHMENT = -250
    ERROR = -250

    action1 = player1.move(moves1, moves2, score1, score2)
    action2 = player2.move(moves2, moves1, score2, score1)

    if (type(action1) != str) or (len(action1) != 1):
        action1 = ' '
    if (type(action2) != str) or (len(action2) != 1):
        action2 = ' '

    # Update scores
    actions = action1 + action2
    if actions == 'cc':
        score1 += RELEASE
        score2 += RELEASE
    elif actions == 'cb':
        score1 += SEVERE_PUNISHMENT
        score2 += TREAT
    elif actions == 'bc':
        score1 += TREAT
        score2 += SEVERE_PUNISHMENT
    elif actions == 'bb':
        score1 += PUNISHMENT
        score2 += PUNISHMENT
    else:
        score1 += ERROR
        score2 += ERROR

    moves1 += action1 if action1 in 'bc' else ' '
    moves2 += action2 if action2 in 'bc' else ' '

    return score1, score2, moves1, moves2

def play_iterative_rounds(player1, player2):
    rounds = random.randint(100, 200)
    moves1, moves2 = '', ''
    score1, score2 = 0, 0
    for _ in range(rounds):
        score1, score2, moves1, moves2 = play_round(player1, player2, score1, score2, moves1, moves2)
    return score1, score2, moves1, moves2

def capitalize(history1, history2):
    cap1, cap2 = '', ''
    for a, b in zip(history1, history2):
        if a == 'c':
            b = b.upper()
        if b in 'cC':
            a = a.upper()
        cap1 += a
        cap2 += b
    return cap1, cap2

def play_tournament(modules):
    n = len(modules)
    scores = [[0]*n for _ in range(n)]
    moves = [['']*n for _ in range(n)]

    for i in range(n):
        for j in range(i):
            score1, score2, moves1, moves2 = play_iterative_rounds(modules[i], modules[j])
            moves1, moves2 = capitalize(moves1, moves2)
            scores[i][j] = score1 / len(moves1)
            moves[i][j] = moves1
            scores[j][i] = score2 / len(moves2)
            moves[j][i] = moves2

    return scores, moves

# ---------------------------
# Reporting
# ---------------------------
def make_section0(modules):
    section = '-'*80 + '\nSection 0 - Line up\n' + '-'*80 + '\n'
    for i, mod in enumerate(modules):
        section += f'Player {i} (P{i}): {mod.team_name}, {mod.strategy_name}\n'
        desc = mod.strategy_description
        while desc:
            section += '        ' + desc[:72] + '\n'
            desc = desc[72:]
    return section

def make_section1(modules, scores):
    n = len(modules)
    section = '-'*80 + '\nSection 1 - Player vs. Player\n' + '-'*80 + '\n'
    section += 'Each column shows pts/round earned against each other player:\n'
    section += '        ' + ''.join(f'{("P"+str(i)):>7}' for i in range(n)) + '\n'

    for i in range(n):
        section += f'vs. P{i} :'
        section += ''.join(f'{scores[j][i]:>7.2f}' for j in range(n))
        section += '\n'

    section += 'TOTAL  :'
    section += ''.join(f'{sum(scores[i]):>7.2f}' for i in range(n)) + '\n'
    return section

def make_section2(modules, scores):
    section = '-'*80 + '\nSection 2 - Leaderboard\n' + '-'*80 + '\n'
    section += 'Average points per round:\nRank  Team name (P#):  Score      with strategy name\n'

    leaderboard = [(mod.team_name[:10], f'P{i}', sum(scores[i])/len(modules), mod.strategy_name[:40]) 
                   for i, mod in enumerate(modules)]
    leaderboard.sort(key=lambda x: x[2], reverse=True)

    # Helper function for rank suffix
    def rank_suffix(rank):
        if 10 <= rank % 100 <= 20:
            return 'th'
        if rank % 10 == 1:
            return 'st'
        if rank % 10 == 2:
            return 'nd'
        if rank % 10 == 3:
            return 'rd'
        return 'th'

    for i, (name, Pn, avg, strat) in enumerate(leaderboard):
        rank_str = f'{i+1}{rank_suffix(i+1)}'
        section += f'{rank_str:<5} {name:<10}({Pn}): {avg:>10.2f} points with {strat:<40}\n'

    return section

def make_section3(modules, moves, scores, index):
    section = '-'*80 + f'\nSection 3 - Game Data for Team {modules[index].team_name}\n' + '-'*80 + '\n'
    n = len(modules)
    for j in range(n):
        if j == index:
            continue
        section += f'{scores[index][j]:.2f} pt/round: {modules[index].team_name} (P{index}) "{modules[index].strategy_name}"\n'
        section += f'{scores[j][index]:.2f} pt/round: {modules[j].team_name} (P{j}) "{modules[j].strategy_name}"\n'

        hist1, hist2 = moves[index][j], moves[j][index]
        while hist1:
            section += hist1[:80] + '\n' + hist2[:80] + '\n\n'
            hist1 = hist1[80:]
            hist2 = hist2[80:]
        section += '-'*80 + '\n'
    return section

def make_reports(modules, scores, moves):
    section0 = make_section0(modules)
    section1 = make_section1(modules, scores)
    section2 = make_section2(modules, scores)
    section3 = [make_section3(modules, moves, scores, i) for i in range(len(modules))]
    return section0, section1, section2, section3

def post_to_file(string, filename='tournament.txt'):
    with open(filename, 'w') as f:
        f.write(string)

def main_play(modules):
    scores, moves = play_tournament(modules)
    section0, section1, section2, section3 = make_reports(modules, scores, moves)
    output = section0 + section1 + section2
    print(output)
    post_to_file(output + ''.join(section3))
    return scores, moves, [section0, section1, section2, section3]

# ---------------------------
# Run tournament
# ---------------------------
if __name__ == '__main__':
    scores, moves, reports = main_play(modules)
# Out:
# Loaded and reloaded module: defRealFunct
# Loaded and reloaded module: kuba
# Loaded and reloaded module: youLost
# Loaded and reloaded module: Chev
# Loaded and reloaded module: AJ
# Loaded and reloaded module: DM
# Loaded and reloaded module: EthanC
# Loaded and reloaded module: Jesters
# Loaded and reloaded module: June_bug
# Loaded and reloaded module: RDGamblers
# Loaded and reloaded module: robertLewandowski
# Loaded and reloaded module: savior
# Loaded and reloaded module: The_Finnegansy
# Loaded and reloaded module: Tit_for_tat
# Loaded and reloaded module: Torrential
# Loaded and reloaded module: trustMe
# Loaded and reloaded module: Y
# --------------------------------------------------------------------------------
# Section 0 - Line up
# --------------------------------------------------------------------------------
# Player 0 (P0): defRealFunct, random until after 10 rounds
#         randomly chooses letters
# Player 1 (P1): kuba, Fights back when attacked
#         Doubles amount of attacks when attacked
# Player 2 (P2): youLost, opposite
#         Do the opposite of what the oppenent did the turn before
# Player 3 (P3): Chev, Cooperate until too many betrayals
#         My strategy draw c until my oppentent backstabs me twice in a row and th
#         en it draws b
# Player 4 (P4): AJ, Figth back hard
#         If attacked, fight back 3x what the opponent attacked
# Player 5 (P5): DM, Last move
#         My first choice is always b, and then depends on opponent's choice. If t
#         heir las choice was 'b' my program will return 'b' in next round, same w
#         ith 'c', also one in every 50s round there is 1 b
# Player 6 (P6): EthanC.py, HALFNHALF
#         The code runs backstab half of the time and cooperate half of the time
# Player 7 (P7): Jesters, Red Herring
#         A set start to throw off the oppenent that then devolves into randomness
#          and constants.
# Player 8 (P8): June_bug, Cooperate
#         My strategy is cooperating unless bakstabbed, use what opponnent used la
#         st round
# Player 9 (P9): RDGamblers, betray than randomness than betray
#         betray 4 times than random spilt and repeat
# Player 10 (P10): ,
# Player 11 (P11): Savior, cooperate first and backstab
#         cooperates first and if the user cooperates first it continues to cooper
#         ate and if the previous turn is backstab it backstabs. If the opponent h
#         as backstabed 40 times in total it backstabs always.
# Player 12 (P12): The_Finnegansy, Starts coupreate then betray and digs its way out of betray cycle
#         My strategy draws c at first then switches to b until it can trust the o
#         ther opponent
# Player 13 (P13): Tit_for_tat, Randomness until see betrayal patten in opponent
#         Randomly chooses b/c until certain patterns are recognized then it acts
#         accordingly
# Player 14 (P14): Torrential, get other points down then keep them down
#         it starts with c until it gets a chance to put a b to lower the enemy po
#         ints the  is keep them lower with a b
# Player 15 (P15): trustMe, backstab
#         back stab all the time until i win
# Player 16 (P16): Y, Last move of their history
#         My code starts with b and their history and then if b in their history r
#         eturns bbb.
# --------------------------------------------------------------------------------
# Section 1 - Player vs. Player
# --------------------------------------------------------------------------------
# Each column shows pts/round earned against each other player:
#              P0     P1     P2     P3     P4     P5     P6     P7     P8     P9    P10    P11    P12    P13    P14    P15    P16
# vs. P0 :   0.00-254.63-492.81-253.55-253.97-249.32-248.20-405.66-251.09-276.53-496.25-251.44-249.25-250.82-250.00-249.47-250.00
# vs. P1 :-243.52   0.00-100.51   0.00   0.00  -3.59-245.24 -71.24   0.00-149.38-244.85   0.00-243.21-100.76-242.34   0.00-250.00
# vs. P2 :  94.24-251.28   0.00  88.85-250.00-158.40  97.18-213.55-162.50 -73.21-492.86 -64.57 -75.00  76.03-500.00  90.50-250.00
# vs. P3 :-240.78   0.00-489.57   0.00   0.00   2.37-245.98-309.15   0.00-268.39-487.12   0.00-244.31-246.46-243.40   0.00-250.00
# vs. P4 :-244.44   0.00-245.04   0.00   0.00-246.51-243.81-241.47   0.00-246.83-245.48   0.00-244.66-244.26-244.54   0.00-250.00
# vs. P5 :-249.32 -17.96-168.00 -11.83-250.00   0.00-250.00-151.93-200.00-245.45  -9.83-212.62-249.37-249.47-247.50-249.43-250.00
# vs. P6 :-251.29-253.40-497.98-252.87-254.42-250.00   0.00-401.10-251.66-263.04-498.55-251.56-251.67-250.00-500.00-251.89-250.00
# vs. P7 : -26.42-273.32 -93.55 -72.54-246.12-141.99 -38.46   0.00-126.25 -83.85-188.82-145.37 -76.23-107.95 -59.28 -46.59-250.00
# vs. P8 :-246.74   0.00-162.50   0.00   0.00-200.00-247.68-126.25   0.00-235.75  -9.19   0.00-246.95-235.66-244.55   0.00-250.00
# vs. P9 :-211.22-250.00-278.32-221.76-250.00-245.45-231.74-299.23-239.11   0.00-333.90-231.60-206.17-248.11-238.74-229.21-250.00
# vs. P10 :  97.75-253.68  95.71  85.61-253.23   0.28  97.98  31.06  -4.78  64.73   0.00  -3.55  -1.08  97.66-497.57  92.44-250.00
# vs. P11 :-245.67   0.00-291.34   0.00   0.00-212.62-247.81-178.70   0.00-260.40  -6.83   0.00-246.03-243.37-245.89   0.00-250.00
# vs. P12 :-249.25-251.79-275.00-251.50-251.40-249.37-247.67-335.25-250.00-280.19 -10.75-250.00   0.00-249.44-248.66-250.00-250.00
# vs. P13 :-247.53-246.21-469.42-252.53-254.10-249.47-250.00-226.14-240.31-225.38-496.09-246.69-249.44   0.00-500.00-249.46-250.00
# vs. P14 :-245.77-252.02 100.00-251.74-251.44-247.50 100.00-384.02-250.00-250.66  96.60-250.00-248.66 100.00   0.00-250.00-250.00
# vs. P15 :-249.47   0.00-491.50   0.00   0.00-249.43-247.35-387.50   0.00-263.95-493.60   0.00-244.87-249.46-245.04   0.00-250.00
# vs. P16 :-250.00-250.00-250.00-250.00-250.00-250.00-250.00-250.00-250.00-250.00-250.00-250.00-250.00-250.00-250.00-250.00   0.00
# TOTAL  :-3009.43-2554.28-4109.82-1643.85-2764.68-2951.01-2698.77-3950.14-2225.69-3308.30-4167.55-2157.40-3326.91-2652.08-4757.51-1843.11-4000.00
# --------------------------------------------------------------------------------
# Section 2 - Leaderboard
# --------------------------------------------------------------------------------
# Average points per round:
# Rank  Team name (P#):  Score      with strategy name
# 1st   Chev      (P3):     -96.70 points with Cooperate until too many betrayals
# 2nd   trustMe   (P15):    -108.42 points with backstab
# 3rd   Savior    (P11):    -126.91 points with cooperate first and backstab
# 4th   June_bug  (P8):    -130.92 points with Cooperate
# 5th   kuba      (P1):    -150.25 points with Fights back when attacked
# 6th   Tit_for_ta(P13):    -156.00 points with Randomness until see betrayal patten in
# 7th   EthanC.py (P6):    -158.75 points with HALFNHALF
# 8th   AJ        (P4):    -162.63 points with Figth back hard
# 9th   DM        (P5):    -173.59 points with Last move
# 10th  defRealFun(P0):    -177.03 points with random until after 10 rounds
# 11th  RDGamblers(P9):    -194.61 points with betray than randomness than betray
# 12th  The_Finneg(P12):    -195.70 points with Starts coupreate then betray and digs it
# 13th  Jesters   (P7):    -232.36 points with Red Herring
# 14th  Y         (P16):    -235.29 points with Last move of their history
# 15th  youLost   (P2):    -241.75 points with opposite
# 16th            (P10):    -245.15 points with
# 17th  Torrential(P14):    -279.85 points with get other points down then keep them dow
