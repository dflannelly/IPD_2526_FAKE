# %% [markdown]
# <a href="https://colab.research.google.com/github/dflannelly/IPD_2526_FAKE/blob/main/Iterative_Prisoners_Dilemma_(IPD).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Iterative Prisoner's Dilemma
#
# Below you will get practice creating 'strategies' and then running them against single opponents for analysis. By the end of the page you will create your tournament strategy. Your code will then be paired up against every other class members' code and the class wide tournament results will be published.
#
# The Tournament.
# Either round you will either betray your opponent or cooperate with your opponent.
# 1. If you both cooperate then you both get 0 points
# 2. If you cooperate and your opponent betrays you, you get -500 points and your opponent gets 100 points.
# 3. If you betray and your opponent cooperates, you get 100 points and your opponent gets -500 points.
# 4. If you both betray, you both get -250 points
#
# You will play between 100-200 rounds with your opponent. Your algorithm can learn from earlier rounds in the match by analyzing my_history or their_history which are lists that contain every move that you and your opponent made. You can also use my_score or their_score to let your code adapt depending on how you are doing.
#
# ## Below is some starter challenges that will get you acquainted with the challenge. At the end of the document you will submit your tournament code

# %% [markdown]
# #Example 1: Cooperate Always
# Below is an example of a gullible function. It returns 'c' for cooperate no matter what. Run the code block below to save it to variable space

# %%
# Strategy 1
def cooperate_always():
      return('c')

# %%
cooperate_always()
# Out:
# 'c'

# %% [markdown]
# In this example we will pair up the cooperate_always() function with the wild_card() function below. Run the code block below to save it to variable space.

# %%
# Strategy 2
import random

def wild_card():
  pick = random.choice(('b','c'))
  return(pick)

# %%
wild_card()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2656355321.py in <cell line: 0>()
# ----> 1 wild_card()
#
# NameError: name 'wild_card' is not defined

# %% [markdown]
# #Answer:
# 1. Describe in your own words what the wild_card() function does?

# %% [markdown]
# #Answer:
# 1. Who do you think will win, cooperate_always() or wild_card() why?

# %%
import random
def game():
  counter = 0
  global team1_history
  global team2_history

  cooperate_history = []
  wildcard_history = []

  cooperate_score = 0
  wildcard_score = 0

  game_length = random.randint(100,200)

  for i in range(game_length):
     choice1 = cooperate_always()
     choice2 = wild_card()

     cooperate_history += choice1
     wildcard_history += choice2

     release = 0
     reward = 100
     punishment = -250
     severe_punishment = -500

     if choice1 == 'c' and choice2 =='c':
       cooperate_score +=  release
       wildcard_score += release

     elif choice1 == 'b' and choice2 =='b':
       cooperate_score += punishment
       wildcard_score += punishment

     elif choice1 == 'c' and choice2 =='b':
       cooperate_score += severe_punishment
       wildcard_score += reward

     elif choice1 == 'b' and choice2 =='c':
       cooperate_score += reward
       wildcard_score += severe_punishment

     counter +=1

  print("The Cooperate Always Functions Score Is: ", cooperate_score)
  print("The WildCard Functions Score Is: ",wildcard_score)

  print("Cooperate History Is :", cooperate_history)
  print("Wild Card History Is :", wildcard_history)
game()
# Out:
# The Cooperate Always Functions Score Is:  -44500
# The WildCard Functions Score Is:  8900
# Cooperate History Is : ['c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c']
# Wild Card History Is : ['b', 'b', 'b', 'b', 'c', 'c', 'b', 'c', 'b', 'c', 'c', 'c', 'c', 'c', 'b', 'b', 'b', 'b', 'c', 'b', 'b', 'b', 'b', 'b', 'b', 'c', 'b', 'b', 'b', 'b', 'c', 'b', 'b', 'c', 'b', 'c', 'b', 'c', 'b', 'c', 'c', 'c', 'c', 'c', 'b', 'b', 'c', 'c', 'c', 'c', 'b', 'c', 'c', 'c', 'b', 'b', 'b', 'c', 'c', 'c', 'c', 'b', 'c', 'b', 'b', 'b', 'b', 'c', 'b', 'b', 'b', 'c', 'b', 'c', 'c', 'b', 'b', 'b', 'b', 'b', 'c', 'b', 'c', 'b', 'b', 'b', 'b', 'b', 'c', 'c', 'b', 'c', 'c', 'b', 'b', 'c', 'b', 'b', 'c', 'c', 'c', 'c', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'c', 'c', 'b', 'b', 'c', 'c', 'c', 'b', 'c', 'c', 'c', 'b', 'c', 'b', 'b', 'c', 'b', 'b', 'b', 'b', 'b', 'b', 'c', 'c', 'b', 'b', 'c', 'c', 'b', 'b', 'c', 'b', 'c', 'c', 'c', 'c', 'c', 'b', 'c', 'c', 'b', 'b', 'b', 'c', 'b', 'b', 'c', 'c', 'c', 'b', 'c', 'b', 'b']

# %% [markdown]
# # Making Functions Smarter.
# Both the cooperate always function and the wild card function did not take advantage of looking at past rounds to see what their opponent did. Let's create a smarter function that can play nice with friendly functions but carries a grudge against other functions.

# %%
#Don't Cross Me
def Dont_Cross_Me():
  #for the first round cooperate
  if len(my_history)==0:
    return('c')

  elif 'b' in their_history:
    return('b')
  else:
    return('c')

# %% [markdown]
# Run the game of Dont_Cross_Me() against Cooperate Always

# %%
import random
def game():
  counter = 0
  global my_history
  global their_history

  my_history = []
  their_history = []

  my_score = 0
  their_score = 0

  game_length = random.randint(100,150)

  for i in range(game_length):
     choice1 = Dont_Cross_Me()
     choice2 = cooperate_always()

     my_history += choice1
     their_history += choice2

     release = 0
     reward = 100
     punishment = -250
     severe_punishment = -500

     if choice1 == 'c' and choice2 =='c':
       my_score +=  release
       their_score += release

     elif choice1 == 'b' and choice2 =='b':
       my_score += punishment
       their_score += punishment

     elif choice1 == 'c' and choice2 =='b':
       my_score += severe_punishment
       their_score += reward

     elif choice1 == 'b' and choice2 =='c':
       my_score += reward
       their_score += severe_punishment

     counter +=1

  print("Don't Cross Me Score :", my_score)
  print("Cooperate Always :",their_score)

  print("Don't Cross Me History: ",my_history)
  print("Cooperate Always: ", their_history)
game()
# Out:
# Don't Cross Me Score : 0
# Cooperate Always : 0
# Don't Cross Me History:  ['c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c']
# Cooperate Always:  ['c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c']

# %% [markdown]
# Run the game of Dont_Cross_Me() against betray always

# %%
import random

def betray_always():
  return('b')


def game():
  counter = 0
  global my_history
  global their_history

  my_history = []
  their_history = []

  my_score = 0
  their_score = 0

  game_length = random.randint(100,150)

  for i in range(game_length):
     choice1 = Dont_Cross_Me()
     choice2 = betray_always()

     my_history += choice1
     their_history += choice2

     release = 0
     reward = 100
     punishment = -250
     severe_punishment = -500

     if choice1 == 'c' and choice2 =='c':
       my_score +=  release
       their_score += release

     elif choice1 == 'b' and choice2 =='b':
       my_score += punishment
       their_score += punishment

     elif choice1 == 'c' and choice2 =='b':
       my_score += severe_punishment
       their_score += reward

     elif choice1 == 'b' and choice2 =='c':
       my_score += reward
       their_score += severe_punishment

     counter +=1

  print("Don't Cross Me Score :", my_score)
  print("Betray Always :",their_score)

  print("Don't Cross Me History: ",my_history)
  print("Betray Always: ", their_history)
game()
# Out:
# Don't Cross Me Score : -27750
# Betray Always : -27150
# Don't Cross Me History:  ['c', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b']
# Betray Always:  ['b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b']

# %% [markdown]
# #Answer:
# 1. Look at how Don't Cross Me's performance changed when it competed against cooperate always vs. betray always. What in its code allowed Don't Cross Me to change how it responded?

# %% [markdown]
# # DO
# In the code cell below you are to write your tournament submission function. Your function must include at least 1 if/else statement and you must show that your function can run without flaws against an opponent.
#
# Helpful Hints:
# 1. their_history[-1] is the move that your opponent did last round
# 2. len(my_history) is the round number
# 3. random.choice(('b','c')) would give a 50:50 random choice between b and c ... how would you get a 75:25 b / c split?
# 4. Your strategy doesn't need to just beat one strategy ... your strategies performance will be averaged out over all of the matches against all tournament submissions... do not over optimize your strategy to beat one type of opponent.

# %%
def Mason_Game_Code():
  #for the first round cooperate
  if len(my_history)==0:
    return('c')

  elif 'b' in their_history:
    return('b')
  else:
    return('c')

# %%
import random
def Mason_Game_Code():
  counter = 0
  global my_history
  global their_history
  global my_score
  global their_score

  my_history = []
  their_history = []

  my_score = 0
  their_score = 0

  game_length = random.randint(100,150)

  for i in range(game_length):
     choice1 = Mason_Game_Code()
     choice2 = WildChoice()

     my_history += choice1
     their_history += choice2

     no_punishment= 0
     good_reward = 100
     bad_punishment = -250
     very_bad_punishment = -500

     if choice1 == 'c' and choice2 =='c':
       my_score +=  no_punishment
       their_score += no_punishment

     elif choice1 == 'b' and choice2 =='b':
       my_score +=  bad_punishment
       their_score +=  bad_punishment

     elif choice1 == 'c' and choice2 =='b':
       my_score += very_bad_punishment
       their_score += good_reward

     elif choice1 == 'b' and choice2 =='c':
       my_score += good_reward
       their_score += very_bad_punishment
     counter +=1

  print("Chesse Doodle:", my_score)
  print("Wild: Choice",their_score)

  print("Chesse Doodle: ",my_history)
  print("Wild Choice: ", their_history)
Mason_Game_Code()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipython-input-1607192643.py in <cell line: 0>()
#      50   print("Chesse Doodle: ",my_history)
#      51   print("Wild Choice: ", their_history)
# ---> 52 Mason_Game_Code()
#
# /tmp/ipython-input-1607192643.py in Mason_Game_Code()
#      17
#      18   for i in range(game_length):
# ---> 19      choice1 = Mason_Game_Code()
#      20      choice2 = WildChoice()
#      21
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipython-input-1607192643.py in Mason_Game_Code()
#      17
#      18   for i in range(game_length):
# ---> 19      choice1 = Mason_Game_Code()
#      20      choice2 = WildChoice()
#      21
#
# RecursionError: maximum recursion depth exceeded
